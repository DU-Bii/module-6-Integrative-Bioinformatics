# %% [markdown]
# # WGCNA Network analysis of liver expression data in female mice
#
# __Session 6 Tutorial for Module 6 DUBII 2021__
#
# ##### Costas Bouyioukos Universite de Paris and Anais Baudot CNRS
#
# ## 1. Preliminaries and data input

# %%
#  Code chunk 1
## Display the current working directory
#getwd();
## If necessary, change the path below to the directory where the data files are stored.
## "." means current directory.
#workingDir = ".";
#setwd(workingDir);
# Load the WGCNA package
library(WGCNA);
## The following setting is important, do not omit.
#options(stringsAsFactors = FALSE);
#Read in the female liver data set
femData = read.csv("data/LiverFemale3600.csv");
# Take a quick look at what is in the data set:
dim(femData);
names(femData);
head(femData);
# Out:
# Loading required package: dynamicTreeCut
#
# Loading required package: fastcluster
#
#
# Attaching package: ‘fastcluster’
#
#
# The following object is masked from ‘package:stats’:
#
#     hclust
#
#
#
#
#
# Attaching package: ‘WGCNA’
#
#
# The following object is masked from ‘package:stats’:
#
#     cor
# [1] 3600  143
#   [1] "substanceBXH"   "gene_symbol"    "LocusLinkID"    "ProteomeID"
#   [5] "cytogeneticLoc" "CHROMOSOME"     "StartPosition"  "EndPosition"
#   [9] "F2_2"           "F2_3"           "F2_14"          "F2_15"
#  [13] "F2_19"          "F2_20"          "F2_23"          "F2_24"
#  [17] "F2_26"          "F2_37"          "F2_42"          "F2_43"
#  [21] "F2_45"          "F2_46"          "F2_47"          "F2_48"
#  [25] "F2_51"          "F2_52"          "F2_54"          "F2_63"
#  [29] "F2_65"          "F2_66"          "F2_68"          "F2_69"
#  [33] "F2_70"          "F2_71"          "F2_72"          "F2_78"
#  [37] "F2_79"          "F2_80"          "F2_81"          "F2_83"
#  [41] "F2_86"          "F2_87"          "F2_88"          "F2_89"
#  [45] "F2_107"         "F2_108"         "F2_109"         "F2_110"
#  [49] "F2_111"         "F2_112"         "F2_117"         "F2_119"
#  [53] "F2_125"         "F2_126"         "F2_127"         "F2_141"
#  [57] "F2_142"         "F2_143"         "F2_144"         "F2_145"
#  [61] "F2_154"         "F2_155"         "F2_156"         "F2_157"
#  [65] "F2_162"         "F2_163"         "F2_164"         "F2_165"
#  [69] "F2_166"         "F2_167"         "F2_169"         "F2_180"
#  [73] "F2_181"         "F2_182"         "F2_187"         "F2_188"
#  [77] "F2_189"         "F2_190"         "F2_191"         "F2_192"
#  [81] "F2_194"         "F2_195"         "F2_200"         "F2_201"
#  [85] "F2_212"         "F2_213"         "F2_214"         "F2_215"
#  [89] "F2_221"         "F2_222"         "F2_223"         "F2_224"
#  [93] "F2_225"         "F2_226"         "F2_227"         "F2_228"
#  [97] "F2_241"         "F2_242"         "F2_243"         "F2_244"
# [101] "F2_245"         "F2_247"         "F2_248"         "F2_261"
# [105] "F2_263"         "F2_264"         "F2_270"         "F2_271"
# [109] "F2_272"         "F2_278"         "F2_287"         "F2_288"
# [113] "F2_289"         "F2_290"         "F2_291"         "F2_296"
# [117] "F2_298"         "F2_299"         "F2_300"         "F2_302"
# [121] "F2_303"         "F2_304"         "F2_305"         "F2_306"
# [125] "F2_307"         "F2_308"         "F2_309"         "F2_310"
# [129] "F2_311"         "F2_312"         "F2_320"         "F2_321"
# [133] "F2_323"         "F2_324"         "F2_325"         "F2_326"
# [137] "F2_327"         "F2_328"         "F2_329"         "F2_330"
# [141] "F2_332"         "F2_355"         "F2_357"
#   substanceBXH gene_symbol   LocusLinkID ProteomeID cytogeneticLoc CHROMOSOME
# 1 MMT00000044  1700007N18Rik  69339      286025     0              16
# 2 MMT00000046  Mast2          17776      157466     0               4
# 3 MMT00000051  Ankrd32       105377      321939     0              13
# 4 MMT00000076  0             383154           0     0              16
# 5 MMT00000080  Ldb2           16826      157383     0               5
# 6 MMT00000102  Rdhs          216453           0     10_70.0_cM     10
#   StartPosition EndPosition F2_2     F2_3    ⋯ F2_324    F2_325  F2_326
# 1  50911260      50912491   -0.01810  0.0642 ⋯  0.047700 -0.0488  0.0168
# 2 115215318     115372404   -0.07730 -0.0297 ⋯ -0.049200 -0.0350 -0.0738
# 3  74940309      74982847   -0.02260  0.0617 ⋯  0.000612  0.1210  0.0996
# 4  49345114      49477048   -0.00924 -0.1450 ⋯ -0.270000  0.0803  0.0424
# 5  43546124      43613704   -0.04870  0.0582 ⋯  0.113000 -0.0859 -0.1340
# 6   1337265       1347607    0.17600 -0.1890 ⋯ -0.080000 -0.1200  0.1230
#   F2_327  F2_328   F2_329  F2_330  F2_332  F2_355  F2_357
# 1 -0.0309  0.02740 -0.0310  0.0660 -0.0199 -0.0146  0.065000
# 2 -0.1730 -0.07380 -0.2010 -0.0820 -0.0939  0.0192 -0.049900
# 3  0.1090  0.02730  0.1200 -0.0629 -0.0395  0.1090  0.000253
# 4  0.1610  0.05120  0.2410  0.3890  0.0251 -0.0348  0.114000
# 5  0.0639  0.00731  0.1240 -0.0212  0.0870  0.0512  0.024300
# 6  0.1870  0.05410  0.0699  0.0708  0.1450 -0.0399  0.037500

# %% [markdown]
# **Keep only the part of the data that contains the gene expression and keep the gene names as data frame index.**

# %%
#  Code chunk 2
datExpr0 = as.data.frame(t(femData[, -c(1:8)]));
names(datExpr0) = femData$substanceBXH;
rownames(datExpr0) = names(femData)[-c(1:8)];
datExpr0
# Out:
#        MMT00000044 MMT00000046  MMT00000051 MMT00000076 MMT00000080 MMT00000102
# F2_2   -0.01810000 -0.077300000 -0.02260000 -0.00924000 -0.04870000  0.17600000
# F2_3    0.06420000 -0.029700000  0.06170000 -0.14500000  0.05820000 -0.18900000
# F2_14   0.00006440  0.112000000 -0.12900000  0.02870000 -0.04830000 -0.06500000
# F2_15  -0.05800000 -0.058900000  0.08710000 -0.04390000 -0.03710000 -0.00846000
# F2_19   0.04830000  0.044300000 -0.11500000  0.00425000  0.02510000 -0.00574000
# F2_20  -0.15197410 -0.093800000 -0.06502607 -0.23610000  0.08504274 -0.01807182
# F2_23  -0.00129000  0.093400000  0.00249000 -0.06900000  0.04450000 -0.12500000
# F2_24  -0.23600000  0.026900000 -0.10200000  0.01440000  0.00167000 -0.06820000
# F2_330 -0.02940000 -0.0483000   0.0317000  -0.23700000  0.01770000  0.1610000
# F2_332  0.06670000  0.0933000  -0.2130000   0.02130000  0.07210000  0.0959000
# F2_355  0.14200000  0.0197000   0.2830000   0.00722000  0.04590000  0.1510000
# F2_357  0.05910000 -0.0173000   0.1190000  -0.13700000 -0.03970000  0.1650000
#        MMT00082877 MMT00082899 MMT00082906
# F2_2    0.0291000  -0.00927000  0.04360000
# F2_3    0.0408000  -0.12100000  0.08270000
# F2_14   0.0892000  -0.11400000 -0.08720000
# F2_15   0.0493000  -0.05010000 -0.03900000
# F2_19  -0.0389000   0.00718000  0.07100000
# F2_20  -0.0745188   0.31857000  0.20477010
# F2_23   0.0880000  -0.18200000  0.06190000
# F2_24  -0.1130000  -1.47000000 -0.00794000
# F2_26  -0.1110000   0.46900000 -0.12500000
# F2_37   0.0579000  -0.19800000 -0.05440000
# F2_42  -0.0769622   0.14676530  0.16814150
# F2_43   0.0435000  -1.19000000 -0.09310000
# F2_45   0.1410000  -0.01490000  0.10800000
# F2_46   0.1740000  -0.17700000  0.12700000
# F2_47   0.0749000   0.10200000  0.02560000
# F2_48   0.0372000  -0.03270000  0.05420000
# F2_51  -0.1410000  -0.07650000  0.03820000
# F2_52   0.1630000   0.10600000  0.05080000
# F2_54   0.1640000  -0.32200000  0.05120000
# F2_63   0.0617000  -0.00234000  0.01930000
# F2_65  -0.0011800   0.02380000  0.05100000
# F2_66   0.1760000   0.09310000  0.06270000
# F2_68   0.0501000   0.12700000 -0.04340000
# F2_69   0.1770000  -0.04290000  0.06510000
# F2_70   0.1050000   0.06240000  0.07220000
# F2_71   0.1590000  -0.48500000 -0.18100000
# F2_72   0.0081700   0.01170000  0.06550000
# F2_78   0.0320000  -0.07620000  0.04590000
# F2_79   0.0582121   0.00894777  0.05803361
# F2_80  -0.0980000   0.03890000  0.02930000
# ⋮      ⋮           ⋮           ⋮
# F2_290  0.02820000  0.29400000  0.014700000
# F2_291  0.01710000 -0.27900000 -0.042700000
# F2_296 -0.11920090  0.14713820 -0.020184590
# F2_298  0.16900000 -0.12000000  0.073000000
# F2_299 -0.04310000  0.10300000  0.016900000
# F2_300 -0.20000000  1.80000000  0.186000000
# F2_302 -0.04880000 -0.05880000 -0.123000000
# F2_303  0.00086100 -0.11400000 -0.016400000
# F2_304 -0.06750000  0.01470000 -0.000890000
# F2_305 -0.01440000  0.05590000  0.113000000
# F2_306 -0.06859455  0.03543063 -0.004195396
# F2_307  0.11200000 -0.06330000  0.045800000
# F2_308  0.02860000  0.03650000 -0.000328000
# F2_309  0.02390000  0.32700000  0.040400000
# F2_310 -0.02510000 -0.00595000 -0.055000000
# F2_311 -0.10800000  0.06800000  0.120000000
# F2_312 -0.13700000 -0.05110000 -0.001220000
# F2_320 -0.05760000 -0.08370000  0.021600000
# F2_321 -0.11700000 -0.01220000 -0.042500000
# F2_323  0.13800000 -0.08740000  0.163000000
# F2_324 -0.05280000 -0.09310000  0.094200000
# F2_325  0.16400000 -0.28800000 -0.136000000
# F2_326 -0.09800000 -0.04300000  0.052000000
# F2_327  0.14100000  0.03680000  0.130000000
# F2_328 -0.10300000  0.08060000  0.093700000
# F2_329 -0.15000000  1.30000000  0.156000000
# F2_330 -0.12500000 -0.00208000  0.036100000
# F2_332 -0.12800000 -0.19000000  0.061300000
# F2_355  0.04480000  0.16400000  0.028000000
# F2_357 -0.20000000  0.08780000 -0.034000000

# %% [markdown]
# **Check if there are genes with missing values.**

# %%
#  Code chunk 3
gsg = goodSamplesGenes(datExpr0, verbose = 3);
gsg$allOK
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE

# %% [markdown]
# **All genes are OK!**
#
# #### Cluster the transposed matrix to identify sample outliers.

# %%
#  Code chunk 4
sampleTree = hclust(dist(datExpr0), method = "average");
# Plot the sample tree: Open a graphic output window of size 12 by 10 inches
# The user should change the dimensions if the window is too large or too small.
options(repr.plot.width = 12, repr.plot.height = 10)
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="",
     cex.lab = 1.2, cex.axis = 1.5, cex.main = 2)
# Plot a line to show the cut
abline(h = 15, col = "red");
# Out:
# Plot with title “Sample clustering to detect outliers”

# %% [markdown]
# **Identify the outlier.**

# %%
#  Code chunk 5
# Determine cluster under the line
clust = cutreeStatic(sampleTree, cutHeight = 15, minSize = 10)
table(clust)
# Out:
# clust
#   0   1
#   1 134

# %% [markdown]
# **Remove the outlier and construct the main data frame.**

# %%
#  Code chunk 5
# clust 1 contains the samples we want to keep.
keepSamples = (clust==1)
datExpr = datExpr0[keepSamples, ]
nGenes = ncol(datExpr)
nSamples = nrow(datExpr)

# %% [markdown]
# #### Import the clinical data, preapre and clean it.

# %%
#  Code chunk 7
traitData = read.csv("data/ClinicalTraits.csv");
dim(traitData)
names(traitData)
# remove columns that hold information we do not need.
allTraits = traitData[, -c(31, 16)];
allTraits = allTraits[, c(2, 11:36) ];
dim(allTraits)
names(allTraits)
# Form a data frame analogous to expression data that will hold the clinical traits.
femaleSamples = rownames(datExpr);
traitRows = match(femaleSamples, allTraits$Mice);
datTraits = allTraits[traitRows, -1];
rownames(datTraits) = allTraits[traitRows, 1];
# Out:
# [1] 361  38
#  [1] "X"                  "Mice"               "Number"
#  [4] "Mouse_ID"           "Strain"             "sex"
#  [7] "DOB"                "parents"            "Western_Diet"
# [10] "Sac_Date"           "weight_g"           "length_cm"
# [13] "ab_fat"             "other_fat"          "total_fat"
# [16] "comments"           "X100xfat_weight"    "Trigly"
# [19] "Total_Chol"         "HDL_Chol"           "UC"
# [22] "FFA"                "Glucose"            "LDL_plus_VLDL"
# [25] "MCP_1_phys"         "Insulin_ug_l"       "Glucose_Insulin"
# [28] "Leptin_pg_ml"       "Adiponectin"        "Aortic.lesions"
# [31] "Note"               "Aneurysm"           "Aortic_cal_M"
# [34] "Aortic_cal_L"       "CoronaryArtery_Cal" "Myocardial_cal"
# [37] "BMD_all_limbs"      "BMD_femurs_only"
# [1] 361  27
#  [1] "Mice"               "weight_g"           "length_cm"
#  [4] "ab_fat"             "other_fat"          "total_fat"
#  [7] "X100xfat_weight"    "Trigly"             "Total_Chol"
# [10] "HDL_Chol"           "UC"                 "FFA"
# [13] "Glucose"            "LDL_plus_VLDL"      "MCP_1_phys"
# [16] "Insulin_ug_l"       "Glucose_Insulin"    "Leptin_pg_ml"
# [19] "Adiponectin"        "Aortic.lesions"     "Aneurysm"
# [22] "Aortic_cal_M"       "Aortic_cal_L"       "CoronaryArtery_Cal"
# [25] "Myocardial_cal"     "BMD_all_limbs"      "BMD_femurs_only"

# %% [markdown]
# **Repeat the sample clustering together with a heat-map of the phenotypic data.**

# %%
datTraits
# Out:
#        weight_g length_cm ab_fat other_fat total_fat X100xfat_weight Trigly
# F2_2   38.0     10.5      3.81   2.78      6.59      17.342105        14
# F2_3   33.5     10.8      1.70   2.05      3.75      11.194030       109
# F2_14  33.9     10.0      1.29   1.67      2.96       8.731563         2
# F2_15  44.3     10.3      3.62   3.34      6.96      15.711061        71
# F2_19  32.9      9.7      2.08   1.85      3.93      11.945289        55
# F2_20  44.8     10.3      3.72   3.20      6.92      15.446429        34
# F2_23  36.9     10.0      2.07   2.80      4.87      13.197832       198
# F2_24  39.5     10.0      2.79   2.62      5.41      13.696203       186
# F2_26  42.5      9.9      2.68   4.56      7.24      17.035294       357
# F2_37  25.7      9.4      0.42   0.60      1.02       3.968872       109
# F2_42  39.4     10.2      2.99   2.80      5.79      14.695431       233
# F2_43  35.3     10.7      1.32   1.56      2.88       8.158640        77
# F2_45  45.8     10.4      4.13   2.90      7.03      15.349345        81
# F2_46  26.1      9.7      0.94   0.82      1.76       6.743295        59
# F2_47  23.9      9.2      0.67   0.90      1.57       6.569038        87
# F2_48  27.5      9.6      0.77   0.95      1.72       6.254545        64
# F2_51  37.9     10.5      1.87   3.56      5.43      14.327177       101
# F2_52  38.5     10.8      1.78   3.09      4.87      12.649351       132
# F2_54  46.4     10.5      2.84   5.90      8.74      18.836207       115
# F2_63  43.2     10.5      1.89   3.97      5.86      13.564815        38
# F2_65  40.4     10.5      1.71   4.44      6.15      15.222772        72
# F2_66  38.9      9.8      1.59   4.21      5.80      14.910026        98
# F2_68  32.0      9.9      1.54   2.75      4.29      13.406250        70
# F2_69  34.9      9.9      1.60   3.22      4.82      13.810888        80
# F2_70  23.9      9.8      0.53   1.40      1.93       8.075314        80
# F2_71  40.9     10.0        NA   4.66        NA             NA        38
# F2_72  30.9      9.7      1.67   2.43      4.10      13.268608        44
# F2_78  37.1     10.0      1.79   2.19      3.98      10.727763       108
# F2_79  38.7     11.0      2.68   2.34      5.02      12.971576        63
# F2_80  42.7     10.5      4.10   4.74      8.84      20.702576        41
# ⋮      ⋮        ⋮         ⋮      ⋮         ⋮         ⋮               ⋮
# F2_290 36.9      9.9      2.53   2.26      4.79      12.981030        53
# F2_291 48.5     10.7      2.90   2.97      5.87      12.103093        61
# F2_296 38.8     10.2      3.28   1.64      4.92      12.680412       120
# F2_43   0        0            0            0                  0
# F2_45  18        1            0            0                  1
# F2_46  25        1           10            0                  0
# F2_47  42        3            0            0                  0
# F2_48  56       10            0            0                  0
# F2_51  34        2            5            0                  1
# F2_52   0        0            0            0                  0
# F2_54  24        6            0            0                  0
# F2_63  48        4            0           NA                 NA
# F2_65  33        0            0           NA                 NA
# F2_66  23        6            0           NA                 NA
# F2_68  39       15           21           NA                 NA
# F2_69  12        2            3           NA                 NA
# F2_70   4        0           17           NA                 NA
# F2_71   5        4            3           NA                 NA
# F2_72   3        0            0           NA                 NA
# F2_78   6        4            0           NA                 NA
# F2_79   0        2           11           NA                 NA
# F2_80  18        0            0           NA                 NA
# ⋮      ⋮        ⋮            ⋮            ⋮                  ⋮
# F2_290 16        0           17            0                  0
# F2_291 16        4            0            2                  4
# F2_296  0        0            7            0                  0
# F2_298  6        0            0            0                  0
# F2_299  0        0            0            6                  0
# F2_300  3        3            0            0                 78
# F2_302 22       10            4            1                 52
# F2_303 39        3            0            0                  0
# F2_304  6        1            2            0                  0
# F2_305 16        0            0            0                  0
# F2_306  6        0            4            0                  0
# F2_307 NA       NA           NA            0                  1
# F2_308 27        6            3            0                  0
# F2_309 20        0            0            0                  0
# F2_310 22        0            0            0                  0
# F2_311  0        0            0            0                  0
# F2_312  0        0           13            0                  0
# F2_320 14        0            0            0                  0
# F2_321 25        1           12            0                  0
# F2_323  0        0            0            0                  0
# F2_324 13        0            0            0                  0
# F2_325 19        2            0            0                  1
# F2_326 27       10            0            0                  0
# F2_327 21        6            0            0                  0
# F2_328  0        0            0            0                  0
# F2_329  0        0           13            0                  0
# F2_330  0        0            4            0                  1
# F2_332 38        3            0           NA                 NA
# F2_355 22        0            0           NA                 NA
# F2_357 27        5            0           NA                 NA
#        BMD_all_limbs BMD_femurs_only
# F2_2   NA            NA
# F2_3   NA            NA
# F2_14  NA            NA
# F2_15  NA            NA
# F2_19  NA            NA
# F2_20  NA            NA
# F2_23  NA            NA
# F2_24  NA            NA
# F2_26  NA            NA
# F2_37  NA            NA
# F2_42  NA            NA
# F2_43  NA            NA
# F2_45  NA            NA
# F2_46  NA            NA
# F2_47  NA            NA
# F2_48  NA            NA
# F2_51  NA            NA
# F2_52  NA            NA
# F2_54  NA            NA
# F2_63  NA            NA
# F2_65  NA            NA
# F2_66  NA            NA
# F2_68  NA            NA
# F2_69  NA            NA
# F2_70  NA            NA
# F2_71  NA            NA
# F2_72  NA            NA
# F2_78  NA            NA
# F2_79  NA            NA
# F2_80  NA            NA
# ⋮      ⋮             ⋮
# F2_290     NA             NA
# F2_291 0.0548        0.07730
# F2_296 0.0621        0.09105
# F2_298     NA             NA
# F2_299 0.0575        0.08275
# F2_300 0.0523        0.07460
# F2_302 0.0588        0.08605
# F2_303     NA             NA
# F2_304 0.0553        0.07840
# F2_305     NA             NA
# F2_306     NA             NA
# F2_307     NA             NA
# F2_308 0.0502        0.07210
# F2_309 0.0573        0.07945
# F2_310 0.0560        0.08130
# F2_311 0.0565        0.07995
# F2_312 0.0551        0.07600
# F2_320 0.0591        0.08070
# F2_321 0.0556        0.08035
# F2_323 0.0588        0.08885
# F2_324 0.0529        0.07040
# F2_325 0.0520        0.07350
# F2_326 0.0525        0.07425
# F2_327 0.0509        0.06990
# F2_328 0.0529        0.07245
# F2_329 0.0507        0.06955
# F2_330 0.0588        0.08395
# F2_332 0.0582        0.08310
# F2_355 0.0564        0.07865
# F2_357     NA             NA

# %%
#  Code chunk 8
# Re-cluster samples
sampleTree2 = hclust(dist(datExpr), method = "average")
# Convert traits to a color representation: white means low, red means high, grey means missing entry
traitColors = numbers2colors(datTraits, signed = FALSE);
# Plot the sample dendrogram and the colors underneath.
options(repr.plot.width = 15, repr.plot.height = 12)
plotDendroAndColors(sampleTree2, traitColors,
                    groupLabels = names(datTraits),
                    main = "Sample dendrogram and trait heatmap")
# Out:
# Plot with title “”

# %% [markdown]
# **Save the analysis to an RData file.**

# %%
# Code chunk 9
save(datExpr, datTraits, file = "FemaleLiver-01-dataInput.RData")

# %% [markdown]
# ## 2. Automatic network construction and module detection

# %%
#  Code chunk 10
# Allow multi-threading within WGCNA. This helps speed up certain calculations.
# At present this call is necessary for the code to work.
# Any error here may be ignored but you may want to update WGCNA if you see one.
# See note above.
allowWGCNAThreads()
# Load the data saved in the first part
lnames = load(file = "FemaleLiver-01-dataInput.RData");
#The variable lnames contains the names of loaded variables.
lnames
# Out:
# Allowing multi-threading with up to 8 threads.
# [1] "datExpr"   "datTraits"

# %% [markdown]
# #### The most convenient and automatic way to detect modules and construct a network with WGCNA.
#
# Here the developers of WGCNA are proposing a "soft thresholding" approach. This method identifies a power -to wich the correlation matrix is raised in order to calculate the network adjacency matrix- based on the criterion of scale-free approximation.

# %%
#  Code chunk 11
# Choose a set of soft-thresholding powers
powers = c(c(1:10), seq(from = 12, to = 20, by = 2))
# Call the network topology analysis function
sft = pickSoftThreshold(datExpr, powerVector = powers, verbose = 5)
# Plot the results:
par(mfrow = c(1, 2));
options(repr.plot.width = 14, repr.plot.height = 10);
# Scale-free topology fit index as a function of the soft-thresholding power
plot(sft$fitIndices[,1], -sign(sft$fitIndices[,3])*sft$fitIndices[,2],
     xlab = "Soft Threshold (power)", ylab = "Scale Free Topology Model Fit,signed R^2", type = "n",
     main = paste("Scale independence"));
text(sft$fitIndices[,1], -sign(sft$fitIndices[,3])*sft$fitIndices[,2],
     labels = powers, cex = 0.9, col = "red");
# this line corresponds to using an R^2 cut-off of h
abline(h = 0.90, col = "red")
# Mean connectivity as a function of the soft-thresholding power
plot(sft$fitIndices[,1], sft$fitIndices[,5],
     xlab = "Soft Threshold (power)", ylab = "Mean Connectivity", type = "n",
     main = paste("Mean connectivity"))
text(sft$fitIndices[,1], sft$fitIndices[,5], labels = powers, cex = 0.9, col = "red")
# Out:
# pickSoftThreshold: will use block size 3600.
#  pickSoftThreshold: calculating connectivity for given powers...
#    ..working on genes 1 through 3600 of 3600
#    Power SFT.R.sq  slope truncated.R.sq mean.k. median.k. max.k.
# 1      1   0.0278  0.345          0.456  747.00  762.0000 1210.0
# 2      2   0.1260 -0.597          0.843  254.00  251.0000  574.0
# 3      3   0.3400 -1.030          0.972  111.00  102.0000  324.0
# 4      4   0.5060 -1.420          0.973   56.50   47.2000  202.0
# 5      5   0.6810 -1.720          0.940   32.20   25.1000  134.0
# 6      6   0.9020 -1.500          0.962   19.90   14.5000   94.8
# 7      7   0.9210 -1.670          0.917   13.20    8.6800   84.1
# 8      8   0.9040 -1.720          0.876    9.25    5.3900   76.3
# 9      9   0.8590 -1.700          0.836    6.80    3.5600   70.5
# 10    10   0.8330 -1.660          0.831    5.19    2.3800   65.8
# 11    12   0.8530 -1.480          0.911    3.33    1.1500   58.1
# 12    14   0.8760 -1.380          0.949    2.35    0.5740   51.9
# 13    16   0.9070 -1.300          0.970    1.77    0.3090   46.8
# 14    18   0.9120 -1.240          0.973    1.39    0.1670   42.5
# 15    20   0.9310 -1.210          0.977    1.14    0.0951   38.7
# Plot with title “Mean connectivity”

# %% [markdown]
# ### The actual network construction step.
#
# We choose 6 (or 7 for signed) as the lowest power that constructs a scale free topology.
# And then we instruct the function to generate modules of size 30, merge modules which are more than 25% similar and save the Topological Overlap Matrix in an object.

# %%
#  Code chunk 12
net = blockwiseModules(datExpr, power = 6,
                       TOMType = "unsigned", minModuleSize = 30,
                       reassignThreshold = 1e-6, mergeCutHeight = 0.25,
                       numericLabels = TRUE, pamRespectsDendro = FALSE,
                       saveTOMs = TRUE, nThreads = 8,
                       saveTOMFileBase = "femaleMouseTOM",
                       verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
# Cluster size 3600 broken into 2108 1492
# Cluster size 2108 broken into 1126 982
# Done cluster 1126
# Done cluster 982
# Done cluster 2108
# Done cluster 1492
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will use 8 parallel threads.
#      Fraction of slow calculations: 0.364892
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file femaleMouseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 1 genes from module 1 because their KME is too low.
#      ..removing 1 genes from module 7 because their KME is too low.
#      ..removing 1 genes from module 8 because their KME is too low.
#      ..removing 1 genes from module 21 because their KME is too low.
#   ..reassigning 21 genes from module 1 to modules with higher KME.
#   ..reassigning 26 genes from module 2 to modules with higher KME.
#   ..reassigning 7 genes from module 3 to modules with higher KME.
#   ..reassigning 1 genes from module 4 to modules with higher KME.
#   ..reassigning 2 genes from module 5 to modules with higher KME.
#   ..reassigning 3 genes from module 6 to modules with higher KME.
#   ..reassigning 5 genes from module 7 to modules with higher KME.
#   ..reassigning 1 genes from module 8 to modules with higher KME.
#   ..reassigning 1 genes from module 9 to modules with higher KME.
#   ..reassigning 2 genes from module 11 to modules with higher KME.
#   ..reassigning 1 genes from module 12 to modules with higher KME.
#   ..reassigning 1 genes from module 19 to modules with higher KME.
#   ..reassigning 1 genes from module 20 to modules with higher KME.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.25
#        Calculating new MEs...

# %% [markdown]
# **Here is the modules (as numbers and not colours yet) of each module with its size.**

# %%
colnames(net$MEs)
# Out:
#  [1] "ME9"  "ME7"  "ME1"  "ME4"  "ME16" "ME2"  "ME3"  "ME6"  "ME5"  "ME13"
# [11] "ME18" "ME12" "ME17" "ME8"  "ME10" "ME11" "ME14" "ME15" "ME0"

# %% [markdown]
# **Here is the resuling plot dendrogram of the module construction and the clustering of the genes.**

# %%
#  Code chunk 13
# Convert labels to colors for plotting
mergedColors = labels2colors(net$colors)
mergedColors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
                    "Module colors",
                    dendroLabels = FALSE, hang = 0.03,
                    addGuide = TRUE, guideHang = 0.05)
# Out:
#    [1] "grey"         "turquoise"    "turquoise"    "grey60"
#    [5] "green"        "purple"       "yellow"       "red"
#    [9] "black"        "turquoise"    "turquoise"    "green"
#   [13] "green"        "yellow"       "turquoise"    "green"
#   [17] "green"        "blue"         "blue"         "blue"
#   [21] "midnightblue" "turquoise"    "cyan"         "midnightblue"
#   [25] "brown"        "yellow"       "cyan"         "blue"
#   [29] "yellow"       "magenta"      "green"        "salmon"
#   [33] "green"        "red"          "grey"         "red"
#   [37] "lightgreen"   "brown"        "blue"         "blue"
#   [41] "turquoise"    "greenyellow"  "brown"        "blue"
#   [45] "cyan"         "green"        "red"          "brown"
#   [49] "yellow"       "red"          "red"          "green"
#   [53] "grey"         "turquoise"    "turquoise"    "blue"
#   [57] "midnightblue" "turquoise"    "green"        "turquoise"
#   [61] "brown"        "turquoise"    "turquoise"    "green"
#   [65] "yellow"       "pink"         "tan"          "turquoise"
#   [69] "midnightblue" "turquoise"    "red"          "blue"
#   [73] "green"        "green"        "blue"         "magenta"
#   [77] "turquoise"    "tan"          "blue"         "brown"
#   [81] "green"        "grey"         "yellow"       "brown"
#   [85] "black"        "purple"       "green"        "red"
#   [89] "purple"       "brown"        "midnightblue" "turquoise"
#   [93] "grey60"       "tan"          "brown"        "black"
#   [97] "purple"       "turquoise"    "yellow"       "turquoise"
#  [101] "blue"         "grey"         "blue"         "pink"
#  [105] "green"        "grey"         "black"        "turquoise"
#  [109] "brown"        "turquoise"    "turquoise"    "yellow"
#  [113] "black"        "black"        "brown"        "brown"
#  [117] "turquoise"    "turquoise"    "blue"         "pink"
#  [121] "blue"         "turquoise"    "blue"         "brown"
#  [125] "greenyellow"  "magenta"      "grey60"       "red"
#  [129] "blue"         "pink"         "black"        "blue"
#  [133] "blue"         "turquoise"    "red"          "turquoise"
#  [137] "turquoise"    "blue"         "cyan"         "pink"
#  [141] "green"        "yellow"       "turquoise"    "magenta"
#  [145] "turquoise"    "salmon"       "brown"        "brown"
#  [149] "turquoise"    "turquoise"    "green"        "tan"
#  [153] "green"        "turquoise"    "magenta"      "turquoise"
#  [157] "yellow"       "magenta"      "brown"        "pink"
#  [161] "yellow"       "brown"        "brown"        "brown"
#  [165] "yellow"       "greenyellow"  "yellow"       "brown"
#  [169] "pink"         "tan"          "blue"         "salmon"
#  [173] "lightcyan"    "blue"         "purple"       "lightgreen"
#  [177] "brown"        "greenyellow"  "magenta"      "lightgreen"
#  [181] "brown"        "magenta"      "turquoise"    "brown"
#  [185] "turquoise"    "grey"         "blue"         "pink"
#  [189] "grey60"       "greenyellow"  "salmon"       "greenyellow"
#  [193] "blue"         "green"        "salmon"       "magenta"
#  [197] "pink"         "blue"         "blue"         "green"
#  [201] "brown"        "green"        "turquoise"    "yellow"
#  [205] "blue"         "midnightblue" "midnightblue" "cyan"
#  [209] "yellow"       "turquoise"    "black"        "green"
#  [213] "greenyellow"  "turquoise"    "salmon"       "grey60"
#  [217] "tan"          "blue"         "cyan"         "green"
#  [221] "black"        "turquoise"    "turquoise"    "red"
#  [225] "purple"       "red"          "lightgreen"   "turquoise"
#  [229] "blue"         "blue"         "turquoise"    "turquoise"
#  [233] "red"          "turquoise"    "blue"         "magenta"
#  [237] "blue"         "blue"         "grey60"       "red"
#  [241] "yellow"       "turquoise"    "red"          "turquoise"
#  [245] "tan"          "salmon"       "yellow"       "brown"
#  [249] "brown"        "blue"         "brown"        "blue"
#  [253] "brown"        "red"          "yellow"       "purple"
#  [257] "brown"        "blue"         "turquoise"    "yellow"
#  [261] "red"          "brown"        "red"          "green"
#  [265] "brown"        "tan"          "green"        "red"
#  [269] "salmon"       "yellow"       "turquoise"    "black"
#  [273] "black"        "green"        "yellow"       "turquoise"
#  [277] "brown"        "tan"          "yellow"       "red"
#  [281] "blue"         "cyan"         "brown"        "blue"
#  [285] "brown"        "turquoise"    "greenyellow"  "magenta"
#  [289] "brown"        "brown"        "turquoise"    "turquoise"
#  [293] "turquoise"    "yellow"       "turquoise"    "brown"
#  [297] "blue"         "tan"          "turquoise"    "green"
#  [301] "lightgreen"   "turquoise"    "brown"        "turquoise"
#  [305] "blue"         "yellow"       "grey"         "cyan"
#  [309] "brown"        "lightgreen"   "blue"         "turquoise"
#  [313] "turquoise"    "lightcyan"    "pink"         "yellow"
#  [317] "black"        "black"        "yellow"       "yellow"
#  [321] "cyan"         "green"        "brown"        "black"
#  [325] "red"          "salmon"       "brown"        "grey"
#  [329] "lightcyan"    "blue"         "black"        "black"
#  [333] "pink"         "black"        "brown"        "black"
#  [337] "brown"        "brown"        "salmon"       "yellow"
#  [341] "lightcyan"    "turquoise"    "brown"        "black"
#  [345] "midnightblue" "black"        "turquoise"    "brown"
#  [349] "green"        "yellow"       "green"        "brown"
#  [353] "tan"          "greenyellow"  "tan"          "blue"
#  [357] "green"        "blue"         "greenyellow"  "blue"
#  [361] "black"        "green"        "magenta"      "magenta"
#  [365] "turquoise"    "green"        "brown"        "salmon"
#  [369] "grey60"       "lightgreen"   "green"        "black"
#  [373] "blue"         "turquoise"    "turquoise"    "black"
#  [377] "turquoise"    "tan"          "lightgreen"   "green"
#  [381] "salmon"       "grey"         "green"        "lightcyan"
#  [385] "lightcyan"    "brown"        "brown"        "red"
#  [389] "grey"         "salmon"       "blue"         "pink"
#  [393] "black"        "turquoise"    "turquoise"    "brown"
#  [397] "green"        "yellow"       "midnightblue" "red"
#  [401] "red"          "turquoise"    "cyan"         "midnightblue"
#  [405] "grey60"       "yellow"       "green"        "turquoise"
#  [409] "tan"          "turquoise"    "grey"         "turquoise"
#  [413] "salmon"       "blue"         "green"        "purple"
#  [417] "black"        "greenyellow"  "greenyellow"  "grey"
#  [421] "turquoise"    "red"          "brown"        "turquoise"
#  [425] "blue"         "green"        "blue"         "grey"
#  [429] "red"          "brown"        "black"        "blue"
#  [433] "tan"          "yellow"       "brown"        "blue"
#  [437] "green"        "turquoise"    "red"          "magenta"
#  [441] "tan"          "grey"         "yellow"       "blue"
#  [445] "blue"         "blue"         "lightgreen"   "blue"
#  [449] "turquoise"    "purple"       "yellow"       "red"
#  [453] "brown"        "red"          "turquoise"    "turquoise"
#  [457] "purple"       "pink"         "lightcyan"    "turquoise"
#  [461] "pink"         "tan"          "cyan"         "purple"
#  [465] "brown"        "green"        "brown"        "greenyellow"
#  [469] "blue"         "green"        "blue"         "green"
#  [473] "lightcyan"    "blue"         "brown"        "yellow"
#  [477] "turquoise"    "brown"        "yellow"       "black"
#  [481] "black"        "turquoise"    "grey"         "red"
#  [485] "red"          "red"          "blue"         "lightcyan"
#  [489] "blue"         "yellow"       "grey"         "blue"
#  [493] "black"        "brown"        "green"        "green"
#  [497] "brown"        "pink"         "turquoise"    "turquoise"
#  [501] "turquoise"    "purple"       "red"          "blue"
#  [505] "blue"         "red"          "red"          "yellow"
#  [509] "blue"         "red"          "salmon"       "cyan"
#  [513] "turquoise"    "turquoise"    "purple"       "midnightblue"
#  [517] "turquoise"    "blue"         "tan"          "yellow"
#  [521] "yellow"       "turquoise"    "pink"         "blue"
#  [525] "red"          "brown"        "red"          "yellow"
#  [529] "greenyellow"  "greenyellow"  "pink"         "red"
#  [533] "black"        "yellow"       "purple"       "greenyellow"
#  [537] "blue"         "magenta"      "yellow"       "midnightblue"
#  [541] "brown"        "brown"        "turquoise"    "blue"
#  [545] "yellow"       "green"        "blue"         "turquoise"
#  [549] "turquoise"    "midnightblue" "yellow"       "black"
#  [553] "yellow"       "tan"          "blue"         "green"
#  [557] "brown"        "red"          "black"        "blue"
#  [561] "lightcyan"    "black"        "salmon"       "green"
#  [565] "cyan"         "turquoise"    "salmon"       "tan"
#  [569] "blue"         "blue"         "blue"         "grey"
#  [573] "yellow"       "black"        "pink"         "black"
#  [577] "purple"       "magenta"      "blue"         "brown"
#  [581] "purple"       "yellow"       "purple"       "turquoise"
#  [585] "yellow"       "brown"        "brown"        "green"
#  [589] "magenta"      "salmon"       "green"        "greenyellow"
#  [593] "green"        "lightcyan"    "brown"        "lightcyan"
#  [597] "brown"        "black"        "blue"         "turquoise"
#  [601] "pink"         "black"        "black"        "black"
#  [605] "blue"         "lightgreen"   "grey60"       "blue"
#  [609] "green"        "blue"         "yellow"       "brown"
#  [613] "brown"        "black"        "green"        "yellow"
#  [617] "yellow"       "blue"         "black"        "turquoise"
#  [621] "grey"         "pink"         "turquoise"    "pink"
#  [625] "black"        "brown"        "turquoise"    "blue"
#  [629] "lightcyan"    "pink"         "magenta"      "cyan"
#  [633] "turquoise"    "yellow"       "black"        "turquoise"
#  [637] "magenta"      "turquoise"    "green"        "black"
#  [641] "purple"       "brown"        "salmon"       "brown"
#  [645] "yellow"       "yellow"       "brown"        "blue"
#  [649] "blue"         "black"        "magenta"      "blue"
#  [653] "red"          "turquoise"    "yellow"       "pink"
#  [657] "black"        "pink"         "magenta"      "tan"
#  [661] "brown"        "turquoise"    "red"          "magenta"
#  [665] "green"        "black"        "green"        "brown"
#  [669] "pink"         "brown"        "red"          "red"
#  [673] "green"        "lightcyan"    "cyan"         "greenyellow"
#  [677] "pink"         "lightgreen"   "pink"         "red"
#  [681] "red"          "red"          "blue"         "green"
#  [685] "midnightblue" "blue"         "brown"        "blue"
#  [689] "red"          "green"        "turquoise"    "brown"
#  [693] "pink"         "red"          "turquoise"    "blue"
#  [697] "turquoise"    "brown"        "tan"          "turquoise"
#  [701] "turquoise"    "grey"         "greenyellow"  "green"
#  [705] "red"          "red"          "green"        "turquoise"
#  [709] "black"        "blue"         "purple"       "green"
#  [713] "greenyellow"  "blue"         "black"        "pink"
#  [717] "green"        "yellow"       "pink"         "cyan"
#  [721] "turquoise"    "grey"         "grey60"       "pink"
#  [725] "turquoise"    "turquoise"    "salmon"       "black"
#  [729] "blue"         "brown"        "turquoise"    "red"
#  [733] "turquoise"    "turquoise"    "blue"         "red"
#  [737] "grey60"       "blue"         "blue"         "yellow"
#  [741] "blue"         "pink"         "greenyellow"  "brown"
#  [745] "pink"         "pink"         "pink"         "brown"
#  [749] "turquoise"    "purple"       "green"        "green"
#  [753] "blue"         "turquoise"    "pink"         "blue"
#  [757] "turquoise"    "green"        "brown"        "brown"
#  [761] "green"        "purple"       "lightcyan"    "blue"
#  [765] "red"          "black"        "brown"        "purple"
#  [769] "brown"        "magenta"      "green"        "black"
#  [773] "turquoise"    "yellow"       "yellow"       "blue"
#  [777] "brown"        "pink"         "red"          "blue"
#  [781] "blue"         "blue"         "red"          "midnightblue"
#  [785] "red"          "salmon"       "turquoise"    "brown"
#  [789] "red"          "brown"        "blue"         "green"
#  [793] "turquoise"    "turquoise"    "blue"         "blue"
#  [797] "turquoise"    "turquoise"    "turquoise"    "green"
#  [801] "blue"         "turquoise"    "greenyellow"  "midnightblue"
#  [805] "yellow"       "brown"        "brown"        "blue"
#  [809] "tan"          "magenta"      "red"          "purple"
#  [813] "magenta"      "turquoise"    "red"          "magenta"
#  [817] "grey"         "red"          "yellow"       "brown"
#  [821] "blue"         "brown"        "green"        "red"
#  [825] "tan"          "blue"         "tan"          "turquoise"
#  [829] "red"          "pink"         "blue"         "blue"
#  [833] "brown"        "blue"         "pink"         "pink"
#  [837] "yellow"       "red"          "turquoise"    "black"
#  [841] "brown"        "lightgreen"   "turquoise"    "grey"
#  [845] "purple"       "red"          "brown"        "turquoise"
#  [849] "turquoise"    "green"        "blue"         "brown"
#  [853] "turquoise"    "turquoise"    "yellow"       "midnightblue"
#  [857] "purple"       "yellow"       "blue"         "black"
#  [861] "green"        "greenyellow"  "turquoise"    "brown"
#  [865] "grey60"       "turquoise"    "turquoise"    "turquoise"
#  [869] "yellow"       "pink"         "pink"         "magenta"
#  [873] "greenyellow"  "blue"         "midnightblue" "brown"
#  [877] "red"          "lightgreen"   "purple"       "green"
#  [881] "black"        "green"        "greenyellow"  "green"
#  [885] "midnightblue" "brown"        "turquoise"    "pink"
#  [889] "grey60"       "turquoise"    "yellow"       "yellow"
#  [893] "blue"         "tan"          "blue"         "brown"
#  [897] "red"          "turquoise"    "green"        "yellow"
#  [901] "yellow"       "green"        "greenyellow"  "grey60"
#  [905] "magenta"      "turquoise"    "black"        "brown"
#  [909] "turquoise"    "turquoise"    "yellow"       "brown"
#  [913] "turquoise"    "green"        "turquoise"    "green"
#  [917] "brown"        "turquoise"    "pink"         "magenta"
#  [921] "yellow"       "grey"         "brown"        "blue"
#  [925] "magenta"      "black"        "turquoise"    "blue"
#  [929] "green"        "brown"        "yellow"       "turquoise"
#  [933] "red"          "turquoise"    "black"        "purple"
#  [937] "red"          "pink"         "tan"          "midnightblue"
#  [941] "brown"        "turquoise"    "turquoise"    "yellow"
#  [945] "cyan"         "brown"        "brown"        "tan"
#  [949] "grey"         "turquoise"    "brown"        "purple"
#  [953] "grey"         "purple"       "black"        "yellow"
#  [957] "blue"         "green"        "lightcyan"    "brown"
#  [961] "salmon"       "magenta"      "yellow"       "blue"
#  [965] "turquoise"    "yellow"       "brown"        "greenyellow"
#  [969] "tan"          "red"          "black"        "blue"
#  [973] "turquoise"    "turquoise"    "turquoise"    "red"
#  [977] "yellow"       "brown"        "yellow"       "magenta"
#  [981] "turquoise"    "brown"        "turquoise"    "blue"
#  [985] "blue"         "salmon"       "purple"       "tan"
#  [989] "brown"        "turquoise"    "black"        "pink"
#  [993] "magenta"      "pink"         "turquoise"    "grey"
#  [997] "yellow"       "yellow"       "red"          "yellow"
# [1001] "black"        "blue"         "turquoise"    "red"
# [1005] "purple"       "blue"         "turquoise"    "green"
# [1009] "yellow"       "turquoise"    "yellow"       "greenyellow"
# [1013] "blue"         "turquoise"    "pink"         "greenyellow"
# [1017] "purple"       "yellow"       "magenta"      "turquoise"
# [1021] "black"        "blue"         "turquoise"    "blue"
# [1025] "purple"       "red"          "lightgreen"   "turquoise"
# [1029] "purple"       "cyan"         "magenta"      "pink"
# [1033] "green"        "yellow"       "blue"         "blue"
# [1037] "blue"         "brown"        "salmon"       "magenta"
# [1041] "turquoise"    "brown"        "blue"         "greenyellow"
# [1045] "blue"         "green"        "green"        "brown"
# [1049] "red"          "yellow"       "pink"         "blue"
# [1053] "grey60"       "yellow"       "brown"        "turquoise"
# [1057] "blue"         "yellow"       "turquoise"    "turquoise"
# [1061] "blue"         "black"        "magenta"      "greenyellow"
# [1065] "turquoise"    "yellow"       "blue"         "red"
# [1069] "magenta"      "red"          "pink"         "tan"
# [1073] "lightcyan"    "brown"        "turquoise"    "pink"
# [1077] "turquoise"    "turquoise"    "red"          "green"
# [1081] "brown"        "pink"         "brown"        "brown"
# [1085] "turquoise"    "red"          "grey60"       "blue"
# [1089] "turquoise"    "yellow"       "brown"        "purple"
# [1093] "yellow"       "turquoise"    "turquoise"    "green"
# [1097] "yellow"       "grey"         "lightcyan"    "greenyellow"
# [1101] "magenta"      "brown"        "turquoise"    "grey"
# [1105] "salmon"       "magenta"      "red"          "turquoise"
# [1109] "red"          "blue"         "purple"       "black"
# [1113] "blue"         "brown"        "yellow"       "blue"
# [1117] "midnightblue" "brown"        "greenyellow"  "turquoise"
# [1121] "black"        "red"          "green"        "green"
# [1125] "brown"        "blue"         "brown"        "red"
# [1129] "lightgreen"   "yellow"       "grey60"       "brown"
# [1133] "green"        "turquoise"    "turquoise"    "blue"
# [1137] "yellow"       "red"          "blue"         "red"
# [1141] "salmon"       "red"          "greenyellow"  "yellow"
# [1145] "yellow"       "black"        "blue"         "brown"
# [1149] "brown"        "lightgreen"   "pink"         "purple"
# [1153] "red"          "blue"         "blue"         "greenyellow"
# [1157] "black"        "salmon"       "pink"         "blue"
# [1161] "turquoise"    "red"          "greenyellow"  "salmon"
# [1165] "blue"         "brown"        "yellow"       "grey"
# [1169] "green"        "brown"        "green"        "green"
# [1173] "turquoise"    "blue"         "magenta"      "turquoise"
# [1177] "midnightblue" "turquoise"    "tan"          "brown"
# [1181] "pink"         "green"        "green"        "green"
# [1185] "lightcyan"    "brown"        "grey"         "red"
# [1189] "blue"         "turquoise"    "brown"        "brown"
# [1193] "yellow"       "purple"       "turquoise"    "magenta"
# [1197] "brown"        "turquoise"    "magenta"      "midnightblue"
# [1201] "brown"        "green"        "magenta"      "midnightblue"
# [1205] "brown"        "brown"        "blue"         "black"
# [1209] "magenta"      "green"        "green"        "grey"
# [1213] "greenyellow"  "greenyellow"  "blue"         "grey60"
# [1217] "purple"       "salmon"       "turquoise"    "green"
# [1221] "green"        "turquoise"    "salmon"       "black"
# [1225] "turquoise"    "blue"         "brown"        "red"
# [1229] "greenyellow"  "brown"        "blue"         "yellow"
# [1233] "red"          "blue"         "turquoise"    "magenta"
# [1237] "blue"         "turquoise"    "brown"        "turquoise"
# [1241] "pink"         "tan"          "pink"         "brown"
# [1245] "turquoise"    "turquoise"    "turquoise"    "brown"
# [1249] "yellow"       "yellow"       "purple"       "greenyellow"
# [1253] "brown"        "greenyellow"  "grey"         "lightgreen"
# [1257] "greenyellow"  "green"        "turquoise"    "brown"
# [1261] "turquoise"    "blue"         "magenta"      "turquoise"
# [1265] "turquoise"    "yellow"       "blue"         "brown"
# [1269] "grey"         "blue"         "blue"         "pink"
# [1273] "red"          "greenyellow"  "blue"         "green"
# [1277] "magenta"      "turquoise"    "salmon"       "black"
# [1281] "blue"         "yellow"       "blue"         "pink"
# [1285] "red"          "turquoise"    "turquoise"    "green"
# [1289] "turquoise"    "cyan"         "black"        "red"
# [1293] "black"        "black"        "brown"        "brown"
# [1297] "blue"         "brown"        "red"          "green"
# [1301] "red"          "cyan"         "yellow"       "turquoise"
# [1305] "turquoise"    "blue"         "blue"         "midnightblue"
# [1309] "red"          "salmon"       "brown"        "blue"
# [1313] "black"        "brown"        "salmon"       "brown"
# [1317] "turquoise"    "purple"       "blue"         "yellow"
# [1321] "black"        "magenta"      "yellow"       "greenyellow"
# [1325] "red"          "cyan"         "brown"        "brown"
# [1329] "turquoise"    "grey60"       "turquoise"    "greenyellow"
# [1333] "grey"         "purple"       "brown"        "salmon"
# [1337] "blue"         "pink"         "pink"         "brown"
# [1341] "turquoise"    "turquoise"    "magenta"      "brown"
# [1345] "red"          "brown"        "tan"          "brown"
# [1349] "cyan"         "midnightblue" "yellow"       "magenta"
# [1353] "turquoise"    "black"        "green"        "pink"
# [1357] "pink"         "blue"         "black"        "blue"
# [1361] "yellow"       "blue"         "brown"        "brown"
# [1365] "yellow"       "green"        "brown"        "brown"
# [1369] "turquoise"    "blue"         "midnightblue" "brown"
# [1373] "turquoise"    "turquoise"    "red"          "blue"
# [1377] "blue"         "magenta"      "blue"         "tan"
# [1381] "turquoise"    "green"        "yellow"       "red"
# [1385] "blue"         "red"          "salmon"       "brown"
# [1389] "blue"         "turquoise"    "red"          "yellow"
# [1393] "salmon"       "purple"       "blue"         "green"
# [1397] "black"        "blue"         "magenta"      "black"
# [1401] "turquoise"    "brown"        "brown"        "turquoise"
# [1405] "turquoise"    "turquoise"    "midnightblue" "turquoise"
# [1409] "lightcyan"    "black"        "brown"        "midnightblue"
# [1413] "blue"         "purple"       "purple"       "blue"
# [1417] "brown"        "turquoise"    "brown"        "salmon"
# [1421] "red"          "green"        "cyan"         "yellow"
# [1425] "purple"       "brown"        "blue"         "black"
# [1429] "brown"        "cyan"         "red"          "black"
# [1433] "black"        "brown"        "blue"         "purple"
# [1437] "lightcyan"    "brown"        "lightgreen"   "purple"
# [1441] "purple"       "turquoise"    "lightcyan"    "green"
# [1445] "turquoise"    "blue"         "turquoise"    "green"
# [1449] "black"        "salmon"       "turquoise"    "turquoise"
# [1453] "yellow"       "grey60"       "turquoise"    "grey60"
# [1457] "magenta"      "cyan"         "turquoise"    "red"
# [1461] "blue"         "yellow"       "black"        "pink"
# [1465] "blue"         "yellow"       "turquoise"    "turquoise"
# [1469] "green"        "purple"       "grey60"       "greenyellow"
# [1473] "turquoise"    "turquoise"    "green"        "magenta"
# [1477] "blue"         "magenta"      "green"        "green"
# [1481] "green"        "brown"        "yellow"       "black"
# [1485] "red"          "red"          "green"        "red"
# [1489] "green"        "greenyellow"  "greenyellow"  "brown"
# [1493] "turquoise"    "blue"         "red"          "turquoise"
# [1497] "yellow"       "blue"         "pink"         "brown"
# [1501] "yellow"       "turquoise"    "blue"         "brown"
# [1505] "grey"         "brown"        "turquoise"    "greenyellow"
# [1509] "yellow"       "lightcyan"    "brown"        "tan"
# [1513] "red"          "turquoise"    "turquoise"    "purple"
# [1517] "lightgreen"   "lightcyan"    "brown"        "green"
# [1521] "turquoise"    "red"          "brown"        "green"
# [1525] "yellow"       "black"        "blue"         "turquoise"
# [1529] "green"        "blue"         "red"          "blue"
# [1533] "pink"         "yellow"       "blue"         "red"
# [1537] "yellow"       "salmon"       "blue"         "turquoise"
# [1541] "green"        "blue"         "brown"        "green"
# [1545] "pink"         "blue"         "purple"       "turquoise"
# [1549] "turquoise"    "blue"         "blue"         "brown"
# [1553] "pink"         "turquoise"    "magenta"      "turquoise"
# [1557] "blue"         "red"          "blue"         "turquoise"
# [1561] "purple"       "pink"         "blue"         "yellow"
# [1565] "turquoise"    "yellow"       "green"        "brown"
# [1569] "black"        "turquoise"    "pink"         "turquoise"
# [1573] "yellow"       "magenta"      "grey"         "grey60"
# [1577] "black"        "purple"       "pink"         "tan"
# [1581] "salmon"       "tan"          "tan"          "turquoise"
# [1585] "blue"         "yellow"       "greenyellow"  "blue"
# [1589] "brown"        "red"          "black"        "green"
# [1593] "blue"         "blue"         "brown"        "lightcyan"
# [1597] "red"          "midnightblue" "greenyellow"  "red"
# [1601] "turquoise"    "blue"         "magenta"      "turquoise"
# [1605] "magenta"      "turquoise"    "pink"         "blue"
# [1609] "yellow"       "yellow"       "brown"        "turquoise"
# [1613] "grey"         "blue"         "blue"         "turquoise"
# [1617] "black"        "blue"         "green"        "blue"
# [1621] "black"        "black"        "turquoise"    "tan"
# [1625] "black"        "black"        "greenyellow"  "blue"
# [1629] "salmon"       "yellow"       "salmon"       "turquoise"
# [1633] "magenta"      "cyan"         "turquoise"    "greenyellow"
# [1637] "turquoise"    "turquoise"    "purple"       "red"
# [1641] "pink"         "brown"        "yellow"       "green"
# [1645] "green"        "turquoise"    "greenyellow"  "brown"
# [1649] "black"        "turquoise"    "midnightblue" "magenta"
# [1653] "yellow"       "purple"       "turquoise"    "turquoise"
# [1657] "turquoise"    "black"        "turquoise"    "blue"
# [1661] "lightcyan"    "turquoise"    "greenyellow"  "pink"
# [1665] "brown"        "midnightblue" "black"        "brown"
# [1669] "turquoise"    "greenyellow"  "grey"         "turquoise"
# [1673] "pink"         "black"        "purple"       "pink"
# [1677] "turquoise"    "blue"         "red"          "turquoise"
# [1681] "blue"         "tan"          "green"        "blue"
# [1685] "brown"        "grey"         "turquoise"    "turquoise"
# [1689] "greenyellow"  "red"          "red"          "brown"
# [1693] "turquoise"    "pink"         "turquoise"    "salmon"
# [1697] "green"        "black"        "turquoise"    "grey60"
# [1701] "blue"         "turquoise"    "brown"        "red"
# [1705] "tan"          "turquoise"    "green"        "tan"
# [1709] "tan"          "brown"        "grey"         "black"
# [1713] "black"        "turquoise"    "purple"       "green"
# [1717] "turquoise"    "turquoise"    "turquoise"    "cyan"
# [1721] "turquoise"    "green"        "purple"       "yellow"
# [1725] "turquoise"    "blue"         "tan"          "blue"
# [1729] "green"        "green"        "midnightblue" "cyan"
# [1733] "brown"        "black"        "yellow"       "yellow"
# [1737] "magenta"      "purple"       "pink"         "blue"
# [1741] "magenta"      "greenyellow"  "magenta"      "brown"
# [1745] "lightgreen"   "green"        "black"        "purple"
# [1749] "brown"        "black"        "purple"       "brown"
# [1753] "turquoise"    "yellow"       "magenta"      "magenta"
# [1757] "cyan"         "brown"        "blue"         "brown"
# [1761] "tan"          "tan"          "blue"         "red"
# [1765] "purple"       "blue"         "brown"        "salmon"
# [1769] "turquoise"    "yellow"       "brown"        "green"
# [1773] "blue"         "yellow"       "blue"         "yellow"
# [1777] "yellow"       "black"        "turquoise"    "midnightblue"
# [1781] "grey"         "turquoise"    "pink"         "brown"
# [1785] "purple"       "yellow"       "black"        "yellow"
# [1789] "turquoise"    "green"        "green"        "yellow"
# [1793] "green"        "blue"         "pink"         "grey60"
# [1797] "yellow"       "black"        "yellow"       "turquoise"
# [1801] "yellow"       "grey"         "turquoise"    "purple"
# [1805] "turquoise"    "turquoise"    "turquoise"    "turquoise"
# [1809] "black"        "blue"         "blue"         "blue"
# [1813] "black"        "pink"         "turquoise"    "turquoise"
# [1817] "lightcyan"    "blue"         "tan"          "yellow"
# [1821] "yellow"       "green"        "turquoise"    "blue"
# [1825] "blue"         "turquoise"    "blue"         "yellow"
# [1829] "yellow"       "greenyellow"  "green"        "black"
# [1833] "turquoise"    "red"          "turquoise"    "purple"
# [1837] "blue"         "cyan"         "brown"        "grey"
# [1841] "midnightblue" "red"          "brown"        "blue"
# [1845] "blue"         "red"          "grey60"       "grey60"
# [1849] "midnightblue" "tan"          "green"        "blue"
# [1853] "cyan"         "black"        "green"        "cyan"
# [1857] "tan"          "brown"        "grey60"       "blue"
# [1861] "brown"        "green"        "blue"         "brown"
# [1865] "magenta"      "blue"         "black"        "purple"
# [1869] "tan"          "green"        "pink"         "black"
# [1873] "lightgreen"   "blue"         "turquoise"    "black"
# [1877] "midnightblue" "lightcyan"    "pink"         "green"
# [1881] "blue"         "brown"        "brown"        "grey"
# [1885] "midnightblue" "midnightblue" "grey60"       "lightcyan"
# [1889] "midnightblue" "turquoise"    "black"        "green"
# [1893] "yellow"       "brown"        "turquoise"    "purple"
# [1897] "turquoise"    "lightgreen"   "midnightblue" "midnightblue"
# [1901] "tan"          "blue"         "green"        "yellow"
# [1905] "magenta"      "turquoise"    "blue"         "red"
# [1909] "purple"       "midnightblue" "purple"       "green"
# [1913] "blue"         "turquoise"    "turquoise"    "black"
# [1917] "tan"          "red"          "brown"        "turquoise"
# [1921] "black"        "black"        "black"        "black"
# [1925] "lightcyan"    "green"        "magenta"      "yellow"
# [1929] "grey"         "turquoise"    "lightcyan"    "red"
# [1933] "magenta"      "brown"        "pink"         "turquoise"
# [1937] "blue"         "turquoise"    "pink"         "brown"
# [1941] "grey"         "turquoise"    "purple"       "yellow"
# [1945] "turquoise"    "grey"         "lightcyan"    "lightgreen"
# [1949] "purple"       "yellow"       "yellow"       "yellow"
# [1953] "yellow"       "blue"         "blue"         "pink"
# [1957] "turquoise"    "brown"        "red"          "purple"
# [1961] "turquoise"    "blue"         "yellow"       "salmon"
# [1965] "grey"         "purple"       "blue"         "blue"
# [1969] "cyan"         "grey"         "yellow"       "black"
# [1973] "green"        "midnightblue" "black"        "yellow"
# [1977] "green"        "turquoise"    "tan"          "magenta"
# [1981] "magenta"      "pink"         "turquoise"    "yellow"
# [1985] "pink"         "grey60"       "salmon"       "pink"
# [1989] "tan"          "turquoise"    "blue"         "greenyellow"
# [1993] "green"        "turquoise"    "midnightblue" "green"
# [1997] "turquoise"    "magenta"      "green"        "grey60"
# [2001] "lightgreen"   "black"        "blue"         "yellow"
# [2005] "greenyellow"  "blue"         "cyan"         "turquoise"
# [2009] "turquoise"    "grey"         "brown"        "lightcyan"
# [2013] "brown"        "turquoise"    "yellow"       "black"
# [2017] "black"        "blue"         "red"          "salmon"
# [2021] "green"        "greenyellow"  "lightcyan"    "salmon"
# [2025] "green"        "pink"         "yellow"       "yellow"
# [2029] "brown"        "black"        "midnightblue" "brown"
# [2033] "midnightblue" "red"          "midnightblue" "turquoise"
# [2037] "midnightblue" "black"        "turquoise"    "yellow"
# [2041] "red"          "blue"         "green"        "brown"
# [2045] "blue"         "cyan"         "grey"         "blue"
# [2049] "yellow"       "yellow"       "lightgreen"   "turquoise"
# [2053] "salmon"       "greenyellow"  "turquoise"    "blue"
# [2057] "black"        "turquoise"    "grey"         "turquoise"
# [2061] "turquoise"    "pink"         "yellow"       "yellow"
# [2065] "lightcyan"    "yellow"       "yellow"       "green"
# [2069] "turquoise"    "red"          "turquoise"    "blue"
# [2073] "green"        "lightgreen"   "lightcyan"    "red"
# [2077] "turquoise"    "pink"         "midnightblue" "black"
# [2081] "yellow"       "brown"        "turquoise"    "pink"
# [2085] "green"        "turquoise"    "pink"         "yellow"
# [2089] "turquoise"    "black"        "turquoise"    "blue"
# [2093] "turquoise"    "salmon"       "tan"          "turquoise"
# [2097] "brown"        "turquoise"    "red"          "black"
# [2101] "grey"         "green"        "green"        "blue"
# [2105] "brown"        "pink"         "cyan"         "turquoise"
# [2109] "green"        "green"        "magenta"      "turquoise"
# [2113] "turquoise"    "blue"         "red"          "yellow"
# [2117] "salmon"       "green"        "brown"        "pink"
# [2121] "brown"        "green"        "grey"         "turquoise"
# [2125] "green"        "pink"         "brown"        "yellow"
# [2129] "turquoise"    "grey"         "grey60"       "green"
# [2133] "black"        "tan"          "brown"        "black"
# [2137] "red"          "green"        "blue"         "blue"
# [2141] "brown"        "brown"        "tan"          "greenyellow"
# [2145] "red"          "blue"         "brown"        "pink"
# [2149] "purple"       "black"        "red"          "pink"
# [2153] "red"          "tan"          "turquoise"    "black"
# [2157] "tan"          "brown"        "yellow"       "salmon"
# [2161] "yellow"       "brown"        "turquoise"    "red"
# [2165] "yellow"       "magenta"      "greenyellow"  "greenyellow"
# [2169] "turquoise"    "turquoise"    "brown"        "turquoise"
# [2173] "yellow"       "cyan"         "green"        "blue"
# [2177] "yellow"       "brown"        "magenta"      "brown"
# [2181] "grey"         "turquoise"    "black"        "blue"
# [2185] "red"          "green"        "green"        "magenta"
# [2189] "black"        "yellow"       "salmon"       "blue"
# [2193] "yellow"       "magenta"      "yellow"       "purple"
# [2197] "black"        "blue"         "red"          "brown"
# [2201] "turquoise"    "turquoise"    "red"          "brown"
# [2205] "greenyellow"  "brown"        "yellow"       "brown"
# [2209] "turquoise"    "cyan"         "turquoise"    "green"
# [2213] "blue"         "yellow"       "turquoise"    "brown"
# [2217] "green"        "turquoise"    "cyan"         "cyan"
# [2221] "blue"         "turquoise"    "blue"         "black"
# [2225] "green"        "blue"         "blue"         "pink"
# [2229] "green"        "magenta"      "turquoise"    "blue"
# [2233] "lightcyan"    "red"          "green"        "magenta"
# [2237] "greenyellow"  "green"        "black"        "tan"
# [2241] "yellow"       "blue"         "yellow"       "turquoise"
# [2245] "yellow"       "blue"         "brown"        "pink"
# [2249] "yellow"       "pink"         "grey60"       "tan"
# [2253] "pink"         "pink"         "brown"        "greenyellow"
# [2257] "black"        "black"        "tan"          "grey60"
# [2261] "grey60"       "midnightblue" "black"        "black"
# [2265] "grey"         "turquoise"    "turquoise"    "red"
# [2269] "black"        "brown"        "brown"        "black"
# [2273] "purple"       "turquoise"    "brown"        "green"
# [2277] "magenta"      "cyan"         "salmon"       "black"
# [2281] "red"          "blue"         "blue"         "pink"
# [2285] "yellow"       "purple"       "blue"         "greenyellow"
# [2289] "blue"         "turquoise"    "green"        "blue"
# [2293] "cyan"         "brown"        "green"        "brown"
# [2297] "turquoise"    "red"          "yellow"       "blue"
# [2301] "salmon"       "red"          "blue"         "magenta"
# [2305] "magenta"      "red"          "yellow"       "turquoise"
# [2309] "blue"         "blue"         "brown"        "brown"
# [2313] "black"        "yellow"       "salmon"       "brown"
# [2317] "midnightblue" "yellow"       "magenta"      "blue"
# [2321] "green"        "turquoise"    "cyan"         "pink"
# [2325] "yellow"       "purple"       "blue"         "black"
# [2329] "purple"       "blue"         "brown"        "magenta"
# [2333] "turquoise"    "blue"         "green"        "salmon"
# [2337] "midnightblue" "black"        "black"        "greenyellow"
# [2341] "green"        "cyan"         "salmon"       "red"
# [2345] "turquoise"    "green"        "green"        "salmon"
# [2349] "turquoise"    "black"        "turquoise"    "green"
# [2353] "brown"        "blue"         "tan"          "purple"
# [2357] "blue"         "turquoise"    "turquoise"    "lightcyan"
# [2361] "tan"          "brown"        "cyan"         "turquoise"
# [2365] "turquoise"    "brown"        "salmon"       "red"
# [2369] "pink"         "midnightblue" "cyan"         "yellow"
# [2373] "grey60"       "magenta"      "blue"         "grey60"
# [2377] "red"          "turquoise"    "purple"       "blue"
# [2381] "brown"        "blue"         "yellow"       "blue"
# [2385] "blue"         "yellow"       "blue"         "turquoise"
# [2389] "blue"         "blue"         "yellow"       "lightcyan"
# [2393] "yellow"       "yellow"       "turquoise"    "lightcyan"
# [2397] "brown"        "green"        "turquoise"    "yellow"
# [2401] "blue"         "lightcyan"    "blue"         "turquoise"
# [2405] "yellow"       "brown"        "turquoise"    "blue"
# [2409] "red"          "turquoise"    "brown"        "yellow"
# [2413] "blue"         "black"        "brown"        "red"
# [2417] "purple"       "black"        "blue"         "salmon"
# [2421] "blue"         "red"          "yellow"       "turquoise"
# [2425] "red"          "blue"         "turquoise"    "turquoise"
# [2429] "blue"         "red"          "turquoise"    "blue"
# [2433] "blue"         "tan"          "pink"         "red"
# [2437] "greenyellow"  "blue"         "yellow"       "yellow"
# [2441] "black"        "salmon"       "yellow"       "brown"
# [2445] "yellow"       "lightcyan"    "turquoise"    "brown"
# [2449] "magenta"      "cyan"         "tan"          "lightcyan"
# [2453] "turquoise"    "green"        "brown"        "blue"
# [2457] "red"          "lightgreen"   "blue"         "brown"
# [2461] "yellow"       "brown"        "green"        "magenta"
# [2465] "blue"         "green"        "red"          "purple"
# [2469] "blue"         "blue"         "grey"         "pink"
# [2473] "blue"         "salmon"       "cyan"         "tan"
# [2477] "blue"         "yellow"       "green"        "greenyellow"
# [2481] "turquoise"    "turquoise"    "blue"         "greenyellow"
# [2485] "blue"         "yellow"       "turquoise"    "turquoise"
# [2489] "greenyellow"  "green"        "greenyellow"  "brown"
# [2493] "greenyellow"  "turquoise"    "green"        "grey60"
# [2497] "green"        "cyan"         "green"        "turquoise"
# [2501] "green"        "magenta"      "blue"         "yellow"
# [2505] "brown"        "red"          "black"        "pink"
# [2509] "lightcyan"    "yellow"       "brown"        "brown"
# [2513] "black"        "midnightblue" "blue"         "red"
# [2517] "blue"         "blue"         "grey"         "magenta"
# [2521] "pink"         "black"        "blue"         "salmon"
# [2525] "green"        "turquoise"    "yellow"       "turquoise"
# [2529] "green"        "midnightblue" "pink"         "turquoise"
# [2533] "red"          "yellow"       "yellow"       "salmon"
# [2537] "cyan"         "lightcyan"    "green"        "black"
# [2541] "turquoise"    "pink"         "grey"         "magenta"
# [2545] "brown"        "black"        "red"          "turquoise"
# [2549] "red"          "black"        "blue"         "turquoise"
# [2553] "red"          "blue"         "turquoise"    "turquoise"
# [2557] "salmon"       "turquoise"    "brown"        "yellow"
# [2561] "blue"         "cyan"         "pink"         "brown"
# [2565] "brown"        "yellow"       "green"        "tan"
# [2569] "lightgreen"   "turquoise"    "purple"       "red"
# [2573] "magenta"      "green"        "blue"         "turquoise"
# [2577] "yellow"       "lightcyan"    "lightcyan"    "brown"
# [2581] "pink"         "purple"       "blue"         "green"
# [2585] "pink"         "magenta"      "blue"         "purple"
# [2589] "turquoise"    "brown"        "blue"         "red"
# [2593] "midnightblue" "yellow"       "lightcyan"    "cyan"
# [2597] "salmon"       "grey"         "yellow"       "salmon"
# [2601] "red"          "green"        "yellow"       "yellow"
# [2605] "brown"        "green"        "brown"        "turquoise"
# [2609] "blue"         "cyan"         "brown"        "green"
# [2613] "cyan"         "turquoise"    "turquoise"    "lightcyan"
# [2617] "blue"         "midnightblue" "midnightblue" "brown"
# [2621] "magenta"      "yellow"       "yellow"       "blue"
# [2625] "purple"       "lightgreen"   "red"          "blue"
# [2629] "green"        "blue"         "brown"        "pink"
# [2633] "turquoise"    "magenta"      "yellow"       "turquoise"
# [2637] "brown"        "pink"         "grey60"       "turquoise"
# [2641] "yellow"       "grey"         "brown"        "blue"
# [2645] "magenta"      "brown"        "pink"         "yellow"
# [2649] "red"          "pink"         "black"        "red"
# [2653] "brown"        "red"          "salmon"       "midnightblue"
# [2657] "pink"         "turquoise"    "brown"        "brown"
# [2661] "grey"         "brown"        "green"        "purple"
# [2665] "brown"        "brown"        "red"          "lightcyan"
# [2669] "turquoise"    "brown"        "green"        "turquoise"
# [2673] "blue"         "brown"        "brown"        "brown"
# [2677] "turquoise"    "salmon"       "blue"         "brown"
# [2681] "turquoise"    "tan"          "lightgreen"   "green"
# [2685] "tan"          "green"        "turquoise"    "yellow"
# [2689] "pink"         "green"        "turquoise"    "turquoise"
# [2693] "tan"          "green"        "green"        "brown"
# [2697] "blue"         "blue"         "green"        "yellow"
# [2701] "tan"          "black"        "green"        "salmon"
# [2705] "blue"         "turquoise"    "tan"          "brown"
# [2709] "turquoise"    "turquoise"    "greenyellow"  "grey60"
# [2713] "cyan"         "turquoise"    "blue"         "pink"
# [2717] "black"        "brown"        "black"        "grey"
# [2721] "green"        "turquoise"    "blue"         "blue"
# [2725] "brown"        "black"        "green"        "pink"
# [2729] "salmon"       "turquoise"    "black"        "brown"
# [2733] "black"        "greenyellow"  "red"          "lightcyan"
# [2737] "magenta"      "brown"        "pink"         "grey"
# [2741] "black"        "brown"        "black"        "turquoise"
# [2745] "pink"         "blue"         "turquoise"    "turquoise"
# [2749] "greenyellow"  "turquoise"    "grey60"       "yellow"
# [2753] "salmon"       "lightcyan"    "salmon"       "tan"
# [2757] "green"        "yellow"       "midnightblue" "purple"
# [2761] "yellow"       "black"        "black"        "brown"
# [2765] "blue"         "blue"         "turquoise"    "red"
# [2769] "turquoise"    "tan"          "yellow"       "turquoise"
# [2773] "greenyellow"  "blue"         "brown"        "greenyellow"
# [2777] "magenta"      "turquoise"    "tan"          "blue"
# [2781] "midnightblue" "brown"        "purple"       "lightgreen"
# [2785] "black"        "turquoise"    "brown"        "greenyellow"
# [2789] "pink"         "brown"        "tan"          "brown"
# [2793] "turquoise"    "blue"         "grey"         "blue"
# [2797] "brown"        "tan"          "green"        "brown"
# [2801] "brown"        "grey"         "brown"        "cyan"
# [2805] "midnightblue" "turquoise"    "black"        "turquoise"
# [2809] "turquoise"    "grey"         "pink"         "green"
# [2813] "green"        "magenta"      "lightcyan"    "green"
# [2817] "green"        "turquoise"    "grey"         "purple"
# [2821] "brown"        "turquoise"    "green"        "grey"
# [2825] "cyan"         "tan"          "turquoise"    "magenta"
# [2829] "red"          "grey"         "yellow"       "grey"
# [2833] "blue"         "purple"       "red"          "yellow"
# [2837] "cyan"         "lightgreen"   "black"        "turquoise"
# [2841] "red"          "turquoise"    "turquoise"    "turquoise"
# [2845] "blue"         "green"        "tan"          "yellow"
# [2849] "grey"         "yellow"       "purple"       "grey60"
# [2853] "pink"         "green"        "lightgreen"   "yellow"
# [2857] "purple"       "green"        "blue"         "red"
# [2861] "blue"         "brown"        "turquoise"    "brown"
# [2865] "green"        "pink"         "brown"        "brown"
# [2869] "tan"          "grey"         "pink"         "salmon"
# [2873] "cyan"         "turquoise"    "brown"        "blue"
# [2877] "salmon"       "green"        "turquoise"    "brown"
# [2881] "green"        "turquoise"    "green"        "brown"
# [2885] "yellow"       "green"        "red"          "greenyellow"
# [2889] "grey"         "turquoise"    "turquoise"    "turquoise"
# [2893] "magenta"      "yellow"       "brown"        "black"
# [2897] "cyan"         "yellow"       "pink"         "yellow"
# [2901] "pink"         "turquoise"    "red"          "brown"
# [2905] "blue"         "tan"          "magenta"      "green"
# [2909] "blue"         "red"          "salmon"       "blue"
# [2913] "yellow"       "red"          "turquoise"    "tan"
# [2917] "midnightblue" "green"        "cyan"         "turquoise"
# [2921] "salmon"       "pink"         "turquoise"    "yellow"
# [2925] "greenyellow"  "red"          "green"        "yellow"
# [2929] "green"        "green"        "turquoise"    "black"
# [2933] "brown"        "brown"        "blue"         "blue"
# [2937] "tan"          "brown"        "blue"         "yellow"
# [2941] "turquoise"    "yellow"       "blue"         "greenyellow"
# [2945] "turquoise"    "grey"         "red"          "brown"
# [2949] "magenta"      "grey"         "blue"         "turquoise"
# [2953] "blue"         "yellow"       "turquoise"    "salmon"
# [2957] "magenta"      "black"        "red"          "cyan"
# [2961] "grey60"       "pink"         "greenyellow"  "brown"
# [2965] "pink"         "blue"         "grey60"       "black"
# [2969] "salmon"       "black"        "turquoise"    "grey"
# [2973] "magenta"      "red"          "blue"         "brown"
# [2977] "grey"         "turquoise"    "blue"         "turquoise"
# [2981] "greenyellow"  "green"        "pink"         "grey60"
# [2985] "salmon"       "blue"         "blue"         "green"
# [2989] "midnightblue" "tan"          "salmon"       "red"
# [2993] "blue"         "green"        "turquoise"    "lightcyan"
# [2997] "red"          "pink"         "yellow"       "brown"
# [3001] "pink"         "blue"         "purple"       "red"
# [3005] "blue"         "blue"         "turquoise"    "black"
# [3009] "turquoise"    "greenyellow"  "turquoise"    "turquoise"
# [3013] "magenta"      "yellow"       "turquoise"    "blue"
# [3017] "blue"         "brown"        "yellow"       "blue"
# [3021] "midnightblue" "brown"        "turquoise"    "yellow"
# [3025] "pink"         "magenta"      "yellow"       "brown"
# [3029] "turquoise"    "brown"        "turquoise"    "yellow"
# [3033] "blue"         "blue"         "magenta"      "brown"
# [3037] "cyan"         "blue"         "brown"        "red"
# [3041] "brown"        "green"        "turquoise"    "midnightblue"
# [3045] "yellow"       "blue"         "magenta"      "blue"
# [3049] "brown"        "blue"         "green"        "blue"
# [3053] "red"          "greenyellow"  "green"        "brown"
# [3057] "turquoise"    "pink"         "grey"         "magenta"
# [3061] "greenyellow"  "red"          "turquoise"    "red"
# [3065] "blue"         "brown"        "greenyellow"  "blue"
# [3069] "purple"       "salmon"       "blue"         "green"
# [3073] "yellow"       "blue"         "green"        "purple"
# [3077] "brown"        "black"        "blue"         "turquoise"
# [3081] "brown"        "blue"         "turquoise"    "turquoise"
# [3085] "grey"         "red"          "brown"        "brown"
# [3089] "black"        "turquoise"    "greenyellow"  "brown"
# [3093] "turquoise"    "red"          "green"        "brown"
# [3097] "brown"        "turquoise"    "salmon"       "red"
# [3101] "turquoise"    "turquoise"    "blue"         "brown"
# [3105] "black"        "grey"         "turquoise"    "purple"
# [3109] "black"        "green"        "brown"        "turquoise"
# [3113] "turquoise"    "magenta"      "blue"         "turquoise"
# [3117] "green"        "blue"         "green"        "green"
# [3121] "turquoise"    "turquoise"    "brown"        "midnightblue"
# [3125] "magenta"      "blue"         "green"        "yellow"
# [3129] "blue"         "turquoise"    "tan"          "yellow"
# [3133] "yellow"       "green"        "red"          "black"
# [3137] "blue"         "blue"         "red"          "blue"
# [3141] "turquoise"    "brown"        "pink"         "pink"
# [3145] "brown"        "blue"         "blue"         "pink"
# [3149] "brown"        "brown"        "brown"        "turquoise"
# [3153] "red"          "green"        "turquoise"    "blue"
# [3157] "turquoise"    "turquoise"    "turquoise"    "greenyellow"
# [3161] "blue"         "tan"          "turquoise"    "grey"
# [3165] "brown"        "turquoise"    "green"        "brown"
# [3169] "cyan"         "turquoise"    "brown"        "cyan"
# [3173] "green"        "black"        "tan"          "turquoise"
# [3177] "blue"         "turquoise"    "blue"         "green"
# [3181] "blue"         "yellow"       "yellow"       "salmon"
# [3185] "turquoise"    "turquoise"    "magenta"      "yellow"
# [3189] "salmon"       "yellow"       "turquoise"    "yellow"
# [3193] "green"        "tan"          "yellow"       "blue"
# [3197] "cyan"         "brown"        "turquoise"    "brown"
# [3201] "red"          "brown"        "brown"        "turquoise"
# [3205] "red"          "blue"         "brown"        "turquoise"
# [3209] "green"        "greenyellow"  "blue"         "pink"
# [3213] "turquoise"    "blue"         "turquoise"    "lightcyan"
# [3217] "turquoise"    "pink"         "blue"         "turquoise"
# [3221] "yellow"       "lightcyan"    "brown"        "red"
# [3225] "magenta"      "brown"        "pink"         "blue"
# [3229] "yellow"       "blue"         "yellow"       "brown"
# [3233] "purple"       "lightcyan"    "red"          "yellow"
# [3237] "purple"       "green"        "black"        "tan"
# [3241] "blue"         "purple"       "blue"         "green"
# [3245] "brown"        "blue"         "cyan"         "grey"
# [3249] "yellow"       "green"        "pink"         "lightcyan"
# [3253] "brown"        "green"        "purple"       "grey"
# [3257] "turquoise"    "blue"         "turquoise"    "green"
# [3261] "turquoise"    "tan"          "green"        "brown"
# [3265] "magenta"      "midnightblue" "blue"         "salmon"
# [3269] "turquoise"    "magenta"      "green"        "greenyellow"
# [3273] "purple"       "pink"         "black"        "red"
# [3277] "black"        "turquoise"    "brown"        "turquoise"
# [3281] "lightcyan"    "black"        "pink"         "pink"
# [3285] "yellow"       "blue"         "yellow"       "brown"
# [3289] "yellow"       "turquoise"    "midnightblue" "turquoise"
# [3293] "brown"        "brown"        "yellow"       "red"
# [3297] "turquoise"    "blue"         "red"          "blue"
# [3301] "grey60"       "magenta"      "blue"         "turquoise"
# [3305] "brown"        "red"          "yellow"       "blue"
# [3309] "blue"         "tan"          "turquoise"    "cyan"
# [3313] "midnightblue" "purple"       "brown"        "black"
# [3317] "green"        "pink"         "blue"         "green"
# [3321] "brown"        "salmon"       "turquoise"    "turquoise"
# [3325] "pink"         "purple"       "black"        "turquoise"
# [3329] "yellow"       "grey"         "grey"         "turquoise"
# [3333] "yellow"       "turquoise"    "brown"        "yellow"
# [3337] "cyan"         "black"        "yellow"       "brown"
# [3341] "red"          "turquoise"    "turquoise"    "brown"
# [3345] "tan"          "salmon"       "black"        "blue"
# [3349] "turquoise"    "purple"       "pink"         "green"
# [3353] "grey"         "blue"         "greenyellow"  "greenyellow"
# [3357] "turquoise"    "greenyellow"  "grey"         "black"
# [3361] "turquoise"    "brown"        "salmon"       "yellow"
# [3365] "pink"         "grey60"       "turquoise"    "red"
# [3369] "green"        "blue"         "purple"       "pink"
# [3373] "turquoise"    "green"        "grey"         "pink"
# [3377] "pink"         "purple"       "turquoise"    "turquoise"
# [3381] "brown"        "blue"         "turquoise"    "yellow"
# [3385] "turquoise"    "turquoise"    "magenta"      "yellow"
# [3389] "purple"       "brown"        "black"        "pink"
# [3393] "turquoise"    "midnightblue" "cyan"         "turquoise"
# [3397] "pink"         "brown"        "midnightblue" "cyan"
# [3401] "turquoise"    "yellow"       "brown"        "magenta"
# [3405] "turquoise"    "cyan"         "tan"          "yellow"
# [3409] "salmon"       "blue"         "blue"         "green"
# [3413] "turquoise"    "green"        "blue"         "turquoise"
# [3417] "blue"         "brown"        "grey"         "brown"
# [3421] "red"          "blue"         "brown"        "purple"
# [3425] "black"        "salmon"       "blue"         "brown"
# [3429] "turquoise"    "green"        "blue"         "turquoise"
# [3433] "magenta"      "yellow"       "cyan"         "yellow"
# [3437] "turquoise"    "brown"        "brown"        "green"
# [3441] "yellow"       "brown"        "brown"        "brown"
# [3445] "brown"        "greenyellow"  "lightcyan"    "turquoise"
# [3449] "red"          "brown"        "turquoise"    "red"
# [3453] "salmon"       "black"        "pink"         "blue"
# [3457] "tan"          "turquoise"    "tan"          "lightgreen"
# [3461] "yellow"       "grey"         "green"        "midnightblue"
# [3465] "tan"          "green"        "midnightblue" "turquoise"
# [3469] "turquoise"    "brown"        "turquoise"    "blue"
# [3473] "blue"         "turquoise"    "brown"        "lightgreen"
# [3477] "turquoise"    "green"        "blue"         "turquoise"
# [3481] "turquoise"    "greenyellow"  "green"        "yellow"
# [3485] "blue"         "turquoise"    "turquoise"    "grey"
# [3489] "turquoise"    "black"        "greenyellow"  "yellow"
# [3493] "cyan"         "magenta"      "turquoise"    "red"
# [3497] "red"          "grey"         "green"        "black"
# [3501] "yellow"       "yellow"       "tan"          "blue"
# [3505] "grey"         "brown"        "black"        "yellow"
# [3509] "turquoise"    "turquoise"    "turquoise"    "cyan"
# [3513] "turquoise"    "midnightblue" "lightcyan"    "blue"
# [3517] "turquoise"    "blue"         "green"        "brown"
# [3521] "turquoise"    "yellow"       "brown"        "red"
# [3525] "brown"        "salmon"       "yellow"       "yellow"
# [3529] "turquoise"    "blue"         "yellow"       "turquoise"
# [3533] "green"        "greenyellow"  "brown"        "blue"
# [3537] "pink"         "brown"        "cyan"         "grey"
# [3541] "brown"        "red"          "turquoise"    "red"
# [3545] "blue"         "brown"        "turquoise"    "turquoise"
# [3549] "red"          "green"        "blue"         "turquoise"
# [3553] "black"        "yellow"       "magenta"      "turquoise"
# [3557] "brown"        "yellow"       "brown"        "turquoise"
# [3561] "purple"       "grey"         "yellow"       "turquoise"
# [3565] "pink"         "pink"         "turquoise"    "salmon"
# [3569] "turquoise"    "tan"          "green"        "blue"
# [3573] "blue"         "blue"         "turquoise"    "brown"
# [3577] "red"          "black"        "turquoise"    "cyan"
# [3581] "turquoise"    "lightcyan"    "lightcyan"    "yellow"
# [3585] "turquoise"    "salmon"       "brown"        "turquoise"
# [3589] "brown"        "greenyellow"  "turquoise"    "greenyellow"
# [3593] "black"        "blue"         "turquoise"    "greenyellow"
# [3597] "midnightblue" "yellow"       "grey"         "black"
# Plot with title “”

# %% [markdown]
# **Save results of this part in an .RData file.**

# %%
#  Code chunk 14
moduleLabels = net$colors
moduleColors = labels2colors(net$colors)
MEs = net$MEs;
geneTree = net$dendrograms[[1]];
save(MEs, moduleLabels, moduleColors, geneTree,
     file = "FemaleLiver-02-networkConstruction-auto.RData")

# %% [markdown]
# ## 3. Relating modules to external information and identifying important genes

# %%
#  Code chunk 15
lnames = load(file = "FemaleLiver-01-dataInput.RData");
#The variable lnames contains the names of loaded variables.
lnames
# Load network data saved in the second part.
lnames = load(file = "FemaleLiver-02-networkConstruction-auto.RData");
lnames
# Out:
# [1] "datExpr"   "datTraits"
# [1] "MEs"          "moduleLabels" "moduleColors" "geneTree"

# %% [markdown]
# ### Quantifying module–trait associations
#
# Here we identify modules that are significantly associated with the measured clinical traits.
# We already have a computed summary profile (eigengene) for each module, so then we simply correlate eigengenes with phenotypic traits and look for the most significant associations:

# %%
#  Code chunk 16
# Define numbers of genes and samples
nGenes = ncol(datExpr);
nSamples = nrow(datExpr);
# Recalculate MEs with color labels
MEs0 = moduleEigengenes(datExpr, moduleColors)$eigengenes
MEs = orderMEs(MEs0)
moduleTraitCor = cor(MEs, datTraits, use = "p");
moduleTraitPvalue = corPvalueStudent(moduleTraitCor, nSamples);

# %% [markdown]
# #### Vsualise the module-trait association.
#
# Each module eigengene and its correlation coefficient are ploted here.
# Since we have many a colour code aids the interprettion of the plot.

# %%
#  Code chunk 17
# Will display correlations and their p-values
textMatrix =  paste(signif(moduleTraitCor, 2), "\n(",
                           signif(moduleTraitPvalue, 1), ")", sep = "");
dim(textMatrix) = dim(moduleTraitCor)
par(mar = c(6, 8, 1, 1));
# Display the correlation values within a heatmap plot
labeledHeatmap(Matrix = moduleTraitCor,
               xLabels = names(datTraits),
               yLabels = names(MEs),
               ySymbols = names(MEs),
               colorLabels = FALSE,
               colors = blueWhiteRed(50),
               textMatrix = textMatrix,
               setStdMargins = FALSE,
               cex.text = 0.5,
               zlim = c(-1,1),
               main = paste("Module-trait relationships"))
# Out:
# Plot with title “Module-trait relationships”

# %%
#  Code chunk 18
names(datExpr)[moduleColors=="salmon"]
# Out:
#  [1] "MMT00000743" "MMT00003575" "MMT00004227" "MMT00004614" "MMT00004671"
#  [6] "MMT00005139" "MMT00005900" "MMT00006408" "MMT00007700" "MMT00007875"
# [11] "MMT00008523" "MMT00008789" "MMT00009011" "MMT00009506" "MMT00011470"
# [16] "MMT00012566" "MMT00012675" "MMT00013152" "MMT00014573" "MMT00016374"
# [21] "MMT00018029" "MMT00022101" "MMT00022878" "MMT00024116" "MMT00025608"
# [26] "MMT00026453" "MMT00026786" "MMT00026973" "MMT00028408" "MMT00028522"
# [31] "MMT00029681" "MMT00030442" "MMT00030469" "MMT00030953" "MMT00032143"
# [36] "MMT00032331" "MMT00032979" "MMT00033522" "MMT00035545" "MMT00036605"
# [41] "MMT00038017" "MMT00038022" "MMT00039557" "MMT00041316" "MMT00045905"
# [46] "MMT00046250" "MMT00046920" "MMT00046994" "MMT00047560" "MMT00048501"
# [51] "MMT00049025" "MMT00050061" "MMT00050881" "MMT00052924" "MMT00053283"
# [56] "MMT00053523" "MMT00054020" "MMT00054102" "MMT00054225" "MMT00054501"
# [61] "MMT00055476" "MMT00056215" "MMT00057115" "MMT00058422" "MMT00058679"
# [66] "MMT00059097" "MMT00060232" "MMT00060307" "MMT00061424" "MMT00061944"
# [71] "MMT00062714" "MMT00063274" "MMT00063965" "MMT00063985" "MMT00067143"
# [76] "MMT00067195" "MMT00067953" "MMT00068222" "MMT00068995" "MMT00069238"
# [81] "MMT00069557" "MMT00069683" "MMT00071535" "MMT00072142" "MMT00074126"
# [86] "MMT00074306" "MMT00075896" "MMT00076939" "MMT00077367" "MMT00077659"
# [91] "MMT00078546" "MMT00078837" "MMT00079348" "MMT00081203" "MMT00082255"
# [96] "MMT00082677"

# %% [markdown]
# #### Probe annotation file provided by the manufacturer to facilitate functional annotation.

# %%
#  Code chunk 19
annot = read.csv(file = "data/GeneAnnotation.csv");
dim(annot)
names(annot)
probes = names(datExpr)
probes2annot = match(probes, annot$substanceBXH)
# The following is the number or probes without annotation:
sum(is.na(probes2annot))
# Should return 0.
# Out:
# [1] 23388    34
#  [1] "X"                        "ID"
#  [3] "arrayname"                "substanceBXH"
#  [5] "gene_symbol"              "LocusLinkID"
#  [7] "OfficialGeneSymbol"       "OfficialGeneName"
#  [9] "LocusLinkSymbol"          "LocusLinkName"
# [11] "ProteomeShortDescription" "UnigeneCluster"
# [13] "LocusLinkCode"            "ProteomeID"
# [15] "ProteomeCode"             "SwissprotID"
# [17] "OMIMCode"                 "DirectedTilingPriority"
# [19] "AlternateSymbols"         "AlternateNames"
# [21] "SpeciesID"                "cytogeneticLoc"
# [23] "Organism"                 "clustername"
# [25] "reporterid"               "probeid"
# [27] "sequenceid"               "clusterid"
# [29] "chromosome"               "startcoordinate"
# [31] "endcoordinate"            "strand"
# [33] "sequence_3_to_5_prime"    "sequence_5_to_3_prime"
# [1] 0

# %% [markdown]
# #### Collect all the information for significant genes related to body weight.

# %%
#  Code chunk 20
# Create the starting data frame
geneInfo0 = data.frame(substanceBXH = probes,
                      geneSymbol = annot$gene_symbol[probes2annot],
                      LocusLinkID = annot$LocusLinkID[probes2annot],
                      moduleColor = moduleColors)
                      #geneTraitSignificance,
                      #GSPvalue)
# Order modules by their significance for weight
modOrder = order(-abs(cor(MEs, weight, use = "p")));
# Add module membership information in the chosen order
for (mod in 1:ncol(geneModuleMembership))
{
  oldNames = names(geneInfo0)
  geneInfo0 = data.frame(geneInfo0, geneModuleMembership[, modOrder[mod]],
                         MMPvalue[, modOrder[mod]]);
  names(geneInfo0) = c(oldNames, paste("MM.", modNames[modOrder[mod]], sep=""),
                       paste("p.MM.", modNames[modOrder[mod]], sep=""))
}
# Order the genes in the geneInfo variable first by module color, then by geneTraitSignificance
geneOrder = order(geneInfo0$moduleColor, -abs(geneInfo0$GS.weight));
geneInfo = geneInfo0[geneOrder, ]
# Out:
# Error in cor(MEs, weight, use = "p"): object 'weight' not found
# Traceback:
#
# 1. order(-abs(cor(MEs, weight, use = "p")))
# 2. cor(MEs, weight, use = "p")

# %% [markdown]
# ##### Save the results in an output file for further analysis.

# %%
#  Code chunk 21
write.csv(geneInfo, file = "geneInfo.csv")
# Out:
# Error in is.data.frame(x): object 'geneInfo' not found
# Traceback:
#
# 1. write.csv(geneInfo, file = "geneInfo.csv")
# 2. eval.parent(Call)
# 3. eval(expr, p)
# 4. eval(expr, p)
# 5. write.table(geneInfo, file = "geneInfo.csv", col.names = NA,
#  .     sep = ",", dec = ".", qmethod = "double")
# 6. is.data.frame(x)

# %% [markdown]
# ## 4. Interfacing network analysis with other data such as functional annotation and gene ontology

# %%
#  Code chunk 22
# Load the expression and trait data saved in the first part
lnames = load(file = "FemaleLiver-01-dataInput.RData");
#The variable lnames contains the names of loaded variables.
lnames
# Load network data saved in the second part.
lnames = load(file = "FemaleLiver-02-networkConstruction-auto.RData");
lnames
# Out:
# [1] "datExpr"   "datTraits"
# [1] "MEs"          "moduleLabels" "moduleColors" "geneTree"

# %%
#  Code chunk 23
# Read in the probe annotation
annot = read.csv(file = "data/GeneAnnotation.csv");
# Match probes in the data set to the probe IDs in the annotation file
probes = names(datExpr)
probes2annot = match(probes, annot$substanceBXH)
# Get the corresponding Locuis Link IDs
allLLIDs = annot$LocusLinkID[probes2annot];
# $ Choose interesting modules
intModules = c("brown", "red", "salmon")
for (module in intModules)
{
  # Select module probes
  modGenes = (moduleColors==module)
  # Get their entrez ID codes
  modLLIDs = allLLIDs[modGenes];
  # Write them into a file
  fileName = paste("LocusLinkIDs-", module, ".txt", sep="");
  write.table(as.data.frame(modLLIDs), file = fileName,
              row.names = FALSE, col.names = FALSE)
}
# As background in the enrichment analysis, we will use all probes in the analysis.
fileName = paste("LocusLinkIDs-all.txt", sep="");
write.table(as.data.frame(allLLIDs), file = fileName,
            row.names = FALSE, col.names = FALSE)

# %%
#  Code chunk 24
GOenr = GOenrichmentAnalysis(moduleColors, allLLIDs, organism = "mouse", nBestP = 10);
# Out:
# Warning message in GOenrichmentAnalysis(moduleColors, allLLIDs, organism = "mouse", :
# “This function is deprecated and will be removed in the near future.
# We suggest using the replacement function enrichmentAnalysis
# in R package anRichment, available from the following URL:
# https://labs.genetics.ucla.edu/horvath/htdocs/CoexpressionNetwork/GeneAnnotation/”
# Loading required package: org.Mm.eg.db
#
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
#
#
# Loading required package: GO.db
#  GOenrichmentAnalysis: loading annotation data...
#   ..of the 3038  Entrez identifiers submitted, 2825 are mapped in current GO categories.
#   ..will use 2825 background genes for enrichment calculations.
#   ..preparing term lists (this may take a while)..
#   ..working on label set 1 ..

# %%
anRichment(moduleColors, allLLIDs, organism = "mouse", nBestP = 10);  # Does not work yet.

# %%
#  Code chunk 25
tab = GOenr$bestPTerms[[4]]$enrichment

# %%
#  Code chunk 26
names(tab)

# %%
#  Code chunk 27
write.table(tab, file = "GOEnrichmentTable.csv", sep = ",", quote = TRUE, row.names = FALSE)

# %%
#  Code chunk 28
keepCols = c(1, 2, 5, 6, 7, 12, 13);
screenTab = tab[, keepCols];
# Round the numeric columns to 2 decimal places:
numCols = c(3, 4);
screenTab[, numCols] = signif(apply(screenTab[, numCols], 2, as.numeric), 2)
# Truncate the the term name to at most 40 characters
screenTab[, 7] = substring(screenTab[, 7], 1, 40)
# Shorten the column names:
colnames(screenTab) = c("module", "size", "p-val", "Bonf", "nInTerm", "ont", "term name");
rownames(screenTab) = NULL;
# Set the width of R's output. The reader should play with this number to obtain satisfactory output.
options(width=95)
# Finally, display the enrichment table:
screenTab

# %% [markdown]
# ## 5. Export of networks to external software

# %%
#  Code chunk 29
# Load the expression and trait data saved in the first part
lnames = load(file = "FemaleLiver-01-dataInput.RData");
#The variable lnames contains the names of loaded variables.
lnames
# Load network data saved in the second part.
lnames = load(file = "FemaleLiver-02-networkConstruction-auto.RData");
lnames

# %%
#  Code chunk 30
# Recalculate topological overlap if needed
TOM = TOMsimilarityFromExpr(datExpr, power = 6);
# Read in the annotation file
annot = read.csv(file = "data/GeneAnnotation.csv");
# Select modules
modules = c("brown", "red");
# Select module probes
probes = names(datExpr)
inModule = is.finite(match(moduleColors, modules));
modProbes = probes[inModule];
modGenes = annot$gene_symbol[match(modProbes, annot$substanceBXH)];
# Select the corresponding Topological Overlap
modTOM = TOM[inModule, inModule];
dimnames(modTOM) = list(modProbes, modProbes)
# Export the network into edge and node list files Cytoscape can read
cyt = exportNetworkToCytoscape(modTOM,
  edgeFile = paste("CytoscapeInput-edges-", paste(modules, collapse="-"), ".txt", sep=""),
  nodeFile = paste("CytoscapeInput-nodes-", paste(modules, collapse="-"), ".txt", sep=""),
  weighted = TRUE,
  threshold = 0.05,
  nodeNames = modProbes,
  altNodeNames = modGenes,
  nodeAttr = moduleColors[inModule]);

# %% [markdown]
# __Open these two files as node table and edge table with Cytoscape and inspect the network of the brown-red modules__
